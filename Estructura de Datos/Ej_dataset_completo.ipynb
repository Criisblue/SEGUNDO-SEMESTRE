# %% [markdown]
# IMPORTAR LIBRERÍA

# %%
from dataclasses import dataclass
import re

# %%
data_set=[
    "  1712345678,  jUAN pablo Perez ;Ingeniería de Software-Quito  ",
    "0923456781;MARIA_Elena-Gomez,medicina ; Guayaquil ",
    "  0104567892 |  carlos_ALBERTO  Tipan | AGRONOMIA |Cuenca ",
    "1805678903-AnA_Lucia_Toapanta;Leyes-Ambato  ",
    " 0706789014 , jose LUIS Caicedo;ARQUITECTURA,Manta",
    "1107890125;  Rosa_elena_mora - psIcOloGIA ; Loja ",
    "  0508901236,DIEGO;Armando;VALENCIA-Ingeniería Civil-Latacunga ",
    "2409012347 |sofia herrera|BiOteCnOlOgIa | Santa Elena ",
    " 1310123458 ; Luis pablo cHorlango-SOFTWARE- Portoviejo",
    " 1011234569,  MaRiAnA de jesus parrales - Enfermería , Ibarra",
    "0612345670-RICARDO;FLORES;Agronomia-Riobamba ",
    "  1213456781 |GABRIELA;mendoza|medicina | Babahoyo ",
    " 2214567892;  juan_gabriel-vargas , LEYES ; Orellana ",
    "  0815678903,  LORENA-pazmiño-Ingeniería de Sistemas-Esmeraldas ",
    " 1616789014;CARLOS_ANDRES-CORTES;Arquitectura|Puyo"
]
